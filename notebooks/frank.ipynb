# %%
import requests
from pprint import pprint
import urllib
import random
import numpy
import json
import pandas as pd

# %%
url="https://apps.bea.gov/api/data/?&UserID=40C692EE-CF34-4473-986F-4D9E5BB22C3C&method=GetData&DataSetName=GDPbyIndustry&Year=2018,2020&Industry=all&tableID=1&Frequency=A&ResultFormat=json"

res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.content
data = res.json()
pprint(data)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'FREQUENCY',
#                                           'ParameterValue': 'A'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '40C692EE-CF34-4473-986F-4D9E5BB22C3C'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATA'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'GDPBYINDUSTRY'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'},
#                                          {'ParameterName': 'YEAR',
#                                           'ParameterValue': '2018,2020'},
#                                          {'ParameterName': 'INDUSTRY',
# ...

# %%
table_data = data["BEAAPI"]["Results"][0]["Data"]

# %%
df = pd.DataFrame(table_data)

df.head()
# Out:
#   TableID Frequency  Year Quarter Industry  \
# 0       1         A  2018    2018       11
# 1       1         A  2018    2018    111CA
# 2       1         A  2018    2018    113FF
# 3       1         A  2018    2018       21
# 4       1         A  2018    2018      211
#
#                            IndustrYDescription DataValue NoteRef
# 0  Agriculture, forestry, fishing, and hunting     178.6       1
# 1                                        Farms     140.3       1
# 2    Forestry, fishing, and related activities      38.3       1
# 3                                       Mining     330.8       1
# 4                       Oil and gas extraction     214.8       1

# %%
df[df["IndustrYDescription"].str.contains("Food")]
# Out:
#     TableID Frequency  Year Quarter Industry  \
# 9         1         A  2018    2018    311FT
# 33        1         A  2018    2018      445
# 80        1         A  2018    2018      722
# 109       1         A  2020    2020    311FT
# 133       1         A  2020    2020      445
# 180       1         A  2020    2020      722
#
#                         IndustrYDescription DataValue NoteRef
# 9    Food and beverage and tobacco products     260.5       1
# 33                 Food and beverage stores     154.3       1
# 80        Food services and drinking places     460.3       1
# 109  Food and beverage and tobacco products     273.5       1
# 133                Food and beverage stores     173.7       1
# 180       Food services and drinking places     410.1       1
